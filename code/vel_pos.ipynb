# %%
import time                             # sys time
import numpy as np                      # numpy library for matrix computations
import matplotlib.pyplot as plt         # plot

# %%
with open('logs/vel_pos_1.2_0.1.npy', 'rb') as f:
    vel = np.load(f,allow_pickle=True)
    pos = np.load(f,allow_pickle=True)

pos = np.array([*pos[:,0]])

x_pos = pos[:,0]
x_dist = x_pos[-1] - x_pos[0]
print(x_dist)
# Out:
# 1.4021755644381615

# %%
plt.plot(vel[:,1,0])
plt.plot(vel[:,1,1])
plt.plot(vel[:,1,2])
plt.show()

plt.plot(pos[:,0]) # x position
plt.plot(pos[:,1])
plt.plot(pos[:,2])
plt.show()
